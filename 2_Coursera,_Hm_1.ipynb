# %% [markdown]
# <a href="https://colab.research.google.com/github/GavrilenkoA/train_task_deep_learning/blob/main/2_Coursera%2C_Hm_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/Admin/YandexDisk/Загрузки/height_weight1.csv", index_col='Index')

# %%
data
# Out:
#          Height    Weight
# Index
# 1      65.78331  112.9925
# 2      71.51521  136.4873
# 3      69.39874  153.0269
# 4      68.21660  142.3354
# 5      67.78781  144.2971
# ...         ...       ...
# 24996  69.50215  118.0312
# 24997  64.54826  120.1932
# 24998  64.69855  118.2655
# 24999  67.52918  132.2682
# 25000  68.87761  124.8740
#
# [25000 rows x 2 columns]

# %%
data.head(5)
# Out:
#          Height    Weight
# Index
# 1      65.78331  112.9925
# 2      71.51521  136.4873
# 3      69.39874  153.0269
# 4      68.21660  142.3354
# 5      67.78781  144.2971

# %%
data.plot(y='Height', kind='hist', 
           color='red',  title='Height (inch.) distribution')
# Out:
# <AxesSubplot:title={'center':'Height (inch.) distribution'}, ylabel='Frequency'>

# %%
data.head(5).plot(y="Weight", kind = "hist", color = "green", title = "Weight of first 5 distribution")
# Out:
# <AxesSubplot:title={'center':'Weight of first 5 distribution'}, ylabel='Frequency'>

# %%
def make_bmi(height_inch, weight_pound):
    METER_TO_INCH, KILO_TO_POUND = 39.37, 2.20462
    return (weight_pound / KILO_TO_POUND) / \
           (height_inch / METER_TO_INCH) ** 2

# %%
data
# Out:
#          Height    Weight
# Index
# 1      65.78331  112.9925
# 2      71.51521  136.4873
# 3      69.39874  153.0269
# 4      68.21660  142.3354
# 5      67.78781  144.2971
# ...         ...       ...
# 24996  69.50215  118.0312
# 24997  64.54826  120.1932
# 24998  64.69855  118.2655
# 24999  67.52918  132.2682
# 25000  68.87761  124.8740
#
# [25000 rows x 2 columns]

# %%
data['BMI'] = data.apply(lambda row: make_bmi(row['Height'], 
                                              row['Weight']), axis=1)

# %%
data
# Out:
#          Height    Weight        BMI
# Index
# 1      65.78331  112.9925  18.357573
# 2      71.51521  136.4873  18.762577
# 3      69.39874  153.0269  22.338895
# 4      68.21660  142.3354  21.504526
# 5      67.78781  144.2971  22.077581
# ...         ...       ...        ...
# 24996  69.50215  118.0312  17.178982
# 24997  64.54826  120.1932  20.281866
# 24998  64.69855  118.2655  19.863971
# 24999  67.52918  132.2682  20.392458
# 25000  68.87761  124.8740  18.506018
#
# [25000 rows x 3 columns]

# %%
sns.pairplot(data)

# %%
def weight_category(weight):
    pass
    if weight < 120:
        return 1
    elif weight > 150:
        return 3
    else:
        return 2
data['weight_cat'] = data['Weight'].apply(weight_category)
data
# Out:
#          Height    Weight        BMI  weight_cat
# Index
# 1      65.78331  112.9925  18.357573           1
# 2      71.51521  136.4873  18.762577           2
# 3      69.39874  153.0269  22.338895           3
# 4      68.21660  142.3354  21.504526           2
# 5      67.78781  144.2971  22.077581           2
# ...         ...       ...        ...         ...
# 24996  69.50215  118.0312  17.178982           1
# 24997  64.54826  120.1932  20.281866           2
# 24998  64.69855  118.2655  19.863971           1
# 24999  67.52918  132.2682  20.392458           2
# 25000  68.87761  124.8740  18.506018           2
#
# [25000 rows x 4 columns]

# %%
box = data.boxplot(x = "Весовая категория", y = "Рост")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-e7aa9ee12005> in <module>
# ----> 1 box = data.boxplot(x = "Весовая категория", y = "Рост")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     378     import matplotlib.pyplot as plt
#     379
# --> 380     ax = boxplot(
#     381         self,
#     382         column=column,
#
# ...

# %%
data = data.rename(columns = {"weight_cat" : "Весовая категория", "Height" : "Рост", "Weight" : "Вес"})
ax = sns.boxplot(x = data["Весовая категория"], y = data["Рост"])

# %%
data.plot(x='Вес',y='Рост',kind='scatter', color = "blue", title='Зависимость роста от веса')
# Out:
# <AxesSubplot:title={'center':'Зависимость роста от веса'}, xlabel='Вес', ylabel='Рост'>

# %%
len("fedferf")
# Out:
# 7

# %%
def plus(a, b):
    s = a + b
    return s
plus(5, 6)
# Out:
# 11

# %%
data
# Out:
#            Рост       Вес        BMI  Весовая категория
# Index
# 1      65.78331  112.9925  18.357573                  1
# 2      71.51521  136.4873  18.762577                  2
# 3      69.39874  153.0269  22.338895                  3
# 4      68.21660  142.3354  21.504526                  2
# 5      67.78781  144.2971  22.077581                  2
# ...         ...       ...        ...                ...
# 24996  69.50215  118.0312  17.178982                  1
# 24997  64.54826  120.1932  20.281866                  2
# 24998  64.69855  118.2655  19.863971                  1
# 24999  67.52918  132.2682  20.392458                  2
# 25000  68.87761  124.8740  18.506018                  2
#
# [25000 rows x 4 columns]

# %%
def alg(w, x):
    return (w[0] + w[1] * x)

# %%
#почему не делим на кол-во l, ведь это функционал ошибки
def error(w):
    result = ((data["Вес"] - (w[0] + w[1] * data["Рост"]))**2).sum()
    return result

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.axis([0, 6, 0, 20])
plt.show()

# %%
a = np.linspace(0, 10, 10)
plt.plot(a)

# %%
w1 = [60, 0.05]
w2 = [50, 0.16]
a = data["Вес"].max()
b = data["Вес"].min()
x = np.linspace(b, a)
res1 = alg(w1, x)
res2 = alg(w2, x)
plt.ylabel('Рост')
plt.xlabel("Вес")
plt.plot(x, res1, color='green')
plt.plot(x, res2, color='red')

# %%
def min_error(x):
    return error([50,x])

# %%
w1_graph = np.linspace(-5, 5, 100)
graph_error = [error([50, i]) for i in w1_graph]
plt.xlabel("кэф w1")
plt.ylabel("Функция ошибки")
plt.plot( w1_graph, graph_error, color='purple')

# %%
#from scipy.optimize import minimize_scalar
import scipy.optimize as op
res = minimize_scalar(min_error)
print (res)
# Out:
#      fun: 2883157.0933487676
#     nfev: 9
#      nit: 5
#  success: True
#        x: 1.1351597092091679

# %%
data.plot(x='Вес',y='Рост', color = "blue", kind = "scatter", title = 'Зависимость роста от веса')

start = data["Вес"].min()
end = data["Вес"].max()
a = np.linspace(start, end)
b = [50, res]
c = alg(b, a)
plt.plot(a, c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-02f2644ffe9f> in <module>
#       5 a = np.linspace(start, end)
#       6 b = [50, res]
# ----> 7 c = alg(b, a)
#       8 plt.plot(a, c)
#       9
#
# <ipython-input-162-7cadbe348b07> in alg(w, x)
#       2
#       3 def alg(w, x):
# ----> 4     return (w[0] + w[1] * x)
#       5
#       6
#
# TypeError: unsupported operand type(s) for *: 'OptimizeResult' and 'float'

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(-5, 5)
a = [10] * len(x)

plt.plot(a)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d') # get current axis

# Создаем массивы NumPy с координатами точек по осям X и У. 
# Используем метод meshgrid, при котором по векторам координат 
# создается матрица координат. Задаем нужную функцию Z(x, y).
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Наконец, используем метод *plot_surface* объекта 
# типа Axes3DSubplot. Также подписываем оси.
surf = ax.plot_surface(X, Y, Z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
a = len(X)
b = len(Y)
Z = np.zeros([a, b])

X, Y = np.meshgrid(X, Y)
for i in range(a):
    for j in range(b):
        Z[i, j] = [error( [X[i][j], Y[i][j]] )]

surf = ax.plot_surface(X, Y, Z)
ax.set_xlabel('Intercept')
ax.set_ylabel('Slope')
ax.set_zlabel('Error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-260-9ceb222db9c0> in <module>
#      10 for i in range(a):
#      11     for j in range(b):
# ---> 12         Z[i, j] = [error( [X[i][j], Y[i][j]] )]
#      13
#      14 surf = ax.plot_surface(X, Y, Z)
#
# ValueError: setting an array element with a sequence.

# %%
data.plot(x='Вес',y='Рост',kind='scatter', color='blue', title='Зависимость роста от веса')
# plotting straight line
start = data['Рост'].min()
end = data['Вес'].max()
a = np.linspace(start, end)
as_x = result.x
tu = alg(as_x, a)
plt.plot(a, tu, color='red', label='Optimal values for w0,w1')
plt.legend(loc='best')
plt.show()
# что-то не то сданными,  в аналоговых заданиях на поиск оптимальной прямой, прямая не попадает в облако точек

# %%
result = op.minimize(error,[0,0],bounds=[(-100, 100),(-5,5)], method='L-BFGS-B')
print(result)
# Out:
#       fun: 2539713.314133652
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.04656616, -0.41909516])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 39
#       nit: 5
#      njev: 13
#    status: 0
#   success: True
#         x: array([-82.57539419,   3.08347131])

# %%
def mserror(y, y_pred):
    return  np.mean(y - y_pred)**2
